# %% [markdown]
# ### Simple sampling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
coffee = pd.read_feather('datasets/coffee_ratings_full (1).feather')
coffee.head()
# Out:
#    total_cup_points  species                     owner country_of_origin  \
# 0             90.58  Arabica                 metad plc          Ethiopia
# 1             89.92  Arabica                 metad plc          Ethiopia
# 2             89.75  Arabica  grounds for health admin         Guatemala
# 3             89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc       None  metad plc  2014/2015
# 1                                 metad plc       None  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch       None       None       None
# 3     yidnekachew dabessa coffee plantation       None    wolensu       None
# 4                                 metad plc       None  metad plc  2014/2015
#
#                                  company       altitude  ...  color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# 1      metad agricultural developmet plc      1950-2200  ...  Green
# 2                                   None  1600 - 1800 m  ...   None
# 3  yidnekachew debessa coffee plantation      1800-2200  ...  Green
# 4      metad agricultural developmet plc      1950-2200  ...  Green
#
#   category_two_defects        expiration                  certification_body  \
# 0                  0.0   April 3rd, 2016  METAD Agricultural Development plc
# 1                  1.0   April 3rd, 2016  METAD Agricultural Development plc
# 2                  0.0    May 31st, 2011        Specialty Coffee Association
# 3                  2.0  March 25th, 2016  METAD Agricultural Development plc
# 4                  2.0   April 3rd, 2016  METAD Agricultural Development plc
#
#                       certification_address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       certification_contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters altitude_mean_meters
# 0              1950.0               2200.0               2075.0
# 1              1950.0               2200.0               2075.0
# 2              1600.0               1800.0               1700.0
# 3              1800.0               2200.0               2000.0
# 4              1950.0               2200.0               2075.0
#
# [5 rows x 43 columns]

# %%
# Simple sampling
# With random state set to 42, the same random sample will be selected each time

coffee_sample = coffee.sample(n=20, random_state = 42)
coffee_sample.head()
# Out:
#       total_cup_points  species                                 owner  \
# 764              82.17  Arabica                         essencecoffee
# 887              81.67  Arabica                  fredy gordillo reyes
# 890              81.67  Arabica              jose luis munoz guerrero
# 1293             73.42  Arabica  cafes finos de exportacion s de r.l.
# 259              83.92  Arabica                 cafes tomari sa de cv
#
#      country_of_origin               farm_name lot_number  \
# 764          Guatemala               blue lake       None
# 887             Mexico  union ramal santa cruz       None
# 890             Mexico                    None       None
# 1293          Honduras                 various       None
# 259             Mexico                 cafetal        101
#
#                                        mill    ico_number  \
# 764                                    None      11873168
# 887                  union ramal santa cruz          2496
# 890                        yajalon, chiapas             0
# 1293  cafes finos de exportacion s. de r.l.     13-117-88
# 259                   cafes tomari sa de cv  016-1273-101
#
#                                    company altitude  ...       color  \
# 764                         essence coffee     1500  ...  Blue-Green
# 887       union ramal santa cruz spr de ri     1400  ...       Green
# 890                                   None     1400  ...       Green
# 1293  cafes finos de exportacion s de r.l.     1350  ...       Green
# 259                  cafes tomari sa de cv     1300  ...       Green
#
#      category_two_defects         expiration  \
# 764                   4.0   March 20th, 2016
# 887                   6.0   March 29th, 2014
# 890                   4.0  August 30th, 2013
# 1293                 16.0   April 26th, 2015
# 259                   5.0     July 3rd, 2018
#
#                       certification_body  \
# 764         Blossom Valley International
# 887                              AMECAFE
# 890                              AMECAFE
# 1293        Instituto Hondureño del Café
# 259   Centro Agroecológico del Café A.C.
#
#                          certification_address  \
# 764   fc45352eee499d8470cf94c9827922fb745bf815
# 887   59e396ad6e22a1c22b248f958e1da2bd8af85272
# 890   59e396ad6e22a1c22b248f958e1da2bd8af85272
# 1293  b4660a57e9f8cc613ae5b8f02bfce8634c763ab4
# 259   3b8dfdd621590b424ff64e0b76df7d6a92e1c628
#
#                          certification_contact unit_of_measurement  \
# 764   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 887   0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 890   0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
# 1293  7f521ca403540f81ec99daec7da19c2788393880                   m
# 259   d470dc009281519e30da6ead1c649fcd7670f386                   m
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters
# 764               1500.0               1500.0               1500.0
# 887               1400.0               1400.0               1400.0
# 890               1400.0               1400.0               1400.0
# 1293              1350.0               1350.0               1350.0
# 259               1300.0               1300.0               1300.0
#
# [5 rows x 43 columns]

# %%
# Systematic sampling
sample_size = 20
pop_size = coffee.shape[0]

interval = pop_size // sample_size  # 66, every 66th row will be selected

# We shoulf make sure that the sample is not biased
coffee.iloc[::interval].head()
# Out:
#      total_cup_points  species               owner country_of_origin  \
# 0               90.58  Arabica           metad plc          Ethiopia
# 66              85.50  Arabica       essencecoffee             Kenya
# 132             84.67  Arabica       essencecoffee        Costa Rica
# 198             84.25  Arabica  racafe & cia s.c.a          Colombia
# 264             83.92  Arabica            almacafe          Colombia
#
#                    farm_name lot_number                  mill  ico_number  \
# 0                  metad plc       None             metad plc   2014/2015
# 66                      inoi       None                  inoi  3707361715
# 132  finca salaca las brisas       None  beneficio las brisas    58180422
# 198                     None       None                  None   3-37-4823
# 264                     None  3-37-1606                bachué        3-37
#
#                                company             altitude  ...  color  \
# 0    metad agricultural developmet plc            1950-2200  ...  Green
# 66                      essence coffee                1900m  ...  Green
# 132                     essence coffee                1750m  ...  Green
# 198                 racafe & cia s.c.a  de 1600 a 1950 msnm  ...  Green
# 264                 racafe & cia s.c.a                 None  ...   None
#
#     category_two_defects          expiration  \
# 0                    0.0     April 3rd, 2016
# 66                   3.0      May 22nd, 2016
# 132                  1.0      May 22nd, 2016
# 198                  2.0  October 25th, 2016
# 264                  5.0  January 20th, 2017
#
#                      certification_body  \
# 0    METAD Agricultural Development plc
# 66         Blossom Valley International
# 132        Blossom Valley International
# 198                            Almacafé
# 264                            Almacafé
#
#                         certification_address  \
# 0    309fcf77415a3661ae83e027f7e5f05dad786e44
# 66   fc45352eee499d8470cf94c9827922fb745bf815
# 132  fc45352eee499d8470cf94c9827922fb745bf815
# 198  e493c36c2d076bf273064f7ac23ad562af257a25
# 264  e493c36c2d076bf273064f7ac23ad562af257a25
#
#                         certification_contact unit_of_measurement  \
# 0    19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 66   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 132  de73fc9412358b523d3a641501e542f31d2668b0                   m
# 198  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
# 264  70d3c0c26f89e00fdae6fb39ff54f0d2eb1c38ab                   m
#
#     altitude_low_meters altitude_high_meters altitude_mean_meters
# 0                1950.0               2200.0               2075.0
# 66               1900.0               1900.0               1900.0
# 132              1750.0               1750.0               1750.0
# 198              1600.0               1950.0               1775.0
# 264                 NaN                  NaN                  NaN
#
# [5 rows x 43 columns]

# %%
shuffled = coffee.sample(frac=1)
shuffled = shuffled.reset_index(drop=True).reset_index()

shuffled.plot(x='index', y='category_two_defects', kind='scatter')
plt.show()

# %% [markdown]
# #### Stratified sampling

# %%
from matplotlib.pylab import norm


top_counted_countries = ['Mexico', 'Guatemala', 'Colombia', 'Brazil', 'Taiwan']

top_counted_subset = coffee['country_of_origin'].isin(top_counted_countries)

coffee_ratings_top = coffee[top_counted_subset]

# sampling
coffee_ratings_samp = coffee_ratings_top.sample(frac = 1, random_state= 2022)

coffee_ratings_samp['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Mexico       0.292441
# Colombia     0.226766
# Guatemala    0.224287
# Brazil       0.163569
# Taiwan       0.092937
# Name: proportion, dtype: float64

# %% [markdown]
# #### Proportional stratified sampling

# %%
coffee_ratings_strat = coffee_ratings_top.groupby('country_of_origin')\
                        .sample(frac = 1, random_state= 2022)
                        
coffee_ratings_strat['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Mexico       0.292441
# Colombia     0.226766
# Guatemala    0.224287
# Brazil       0.163569
# Taiwan       0.092937
# Name: proportion, dtype: float64

# %%
coffee_ratings_eq = coffee_ratings_top.groupby('country_of_origin')\
                        .sample(n = 15, random_state= 2022)
                        
coffee_ratings_eq['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Brazil       0.2
# Colombia     0.2
# Guatemala    0.2
# Mexico       0.2
# Taiwan       0.2
# Name: proportion, dtype: float64

# %%
coffee_ratings_weight = coffee_ratings_top
condition = coffee_ratings_weight['country_of_origin'] == 'Taiwan'

coffee_ratings_weight['weight'] = np.where(condition, 2, 1)

coffee_ratings_weight = coffee_ratings_weight.sample(frac = 0.1, weights= 'weight')

coffee_ratings_weight['country_of_origin'].value_counts(normalize=True)
# Out:
# C:\Users\codlw\AppData\Local\Temp\ipykernel_4304\4002134070.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee_ratings_weight['weight'] = np.where(condition, 2, 1)
# country_of_origin
# Mexico       0.296296
# Guatemala    0.234568
# Colombia     0.209877
# Taiwan       0.172840
# Brazil       0.086420
# Name: proportion, dtype: float64

# %%
coffee_ratings_weight[coffee_ratings_weight['weight'] == 2]
# Out:
#       total_cup_points  species                     owner country_of_origin  \
# 962              81.25  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 620              82.67  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 1125             80.00  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 825              81.92  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 482              83.08  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 914              81.50  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 770              82.17  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 1026             80.92  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 919              81.50  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 897              81.58  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 278              83.83  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 1146             79.75  Arabica    lin, che-hao krude 林哲豪            Taiwan
# 269              83.92  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
# 1021             80.92  Arabica  cqi taiwan icp cqi台灣合作夥伴            Taiwan
#
#                                   farm_name     lot_number  \
# 962                jing jing café 晶晶坊青山咖啡教室  2016NA Lot001
# 620             zhuo wu shan coffee 卓武山咖啡農場           None
# 1125           zhang li hong coffee 張立宏咖啡莊園           None
# 825                       dragon coffee 龍咖啡           None
# 482          kan tou mountain coffee 崁頭山咖啡館           None
# 914                                  谷泉咖啡莊園           None
# 770          kan tou mountain coffee 崁頭山咖啡館           None
# 1026              bai he lin coffee 白鶴林咖啡莊園           None
# 919                   good mood coffee 馨晴咖啡           None
# 897              baishengcun coffee 百勝村咖啡莊園    2016 Washed
# 278   優遊吧斯股份有限公司yuyupas international corp.              1
# 1146            baijiada coffee farm佰加達咖啡莊園           None
# 269                                   神谷山莊園           None
# 1021                                  張文進莊園           None
#
#                                 mill ico_number                   company  \
# 962         jing jing café 晶晶坊青山咖啡教室     Taiwan  taiwan coffee laboratory
# 620      zhuo wu shan coffee 卓武山咖啡農場       None        blossom valley宸嶧國際
# 1125    zhang li hong coffee 張立宏咖啡莊園       None        blossom valley宸嶧國際
# 825                dragon coffee 龍咖啡       None        blossom valley宸嶧國際
# 482   kan tou mountain coffee 崁頭山咖啡館     Taiwan  taiwan coffee laboratory
# 914                             寶島咖啡        123                      宸嶧國際
# 770   kan tou mountain coffee 崁頭山咖啡館     Taiwan     red on tree co., ltd.
# 1026       bai he lin coffee 白鶴林咖啡莊園       None        blossom valley宸嶧國際
# 919            good mood coffee 馨晴咖啡     Taiwan     red on tree co., ltd.
# 897       baishengcun coffee 百勝村咖啡莊園     Taiwan  taiwan coffee laboratory
# 278                             none       None                      宸嶧國際
# 1146     baijiada coffee farm佰加達咖啡莊園     Taiwan     red on tree co., ltd.
# 269                            神谷山莊園   Taiwan台灣                      宸嶧國際
# 1021                           張文進莊園   Taiwan台灣                      宸嶧國際
#
#       altitude  ... category_two_defects            expiration  \
# 962        680  ...                  0.0        May 18th, 2017
# 620     1240 m  ...                  0.0   December 26th, 2014
# 1125     250 m  ...                  0.0   December 26th, 2014
# 825     1000 m  ...                  0.0   December 26th, 2014
# 482   700-800m  ...                  0.0        May 18th, 2016
# 914   160-200m  ...                  2.0  September 16th, 2016
# 770      800 m  ...                  0.0        May 29th, 2014
# 1026     688 m  ...                  0.0   December 26th, 2014
# 919      900 m  ...                  0.0     August 18th, 2015
# 897        800  ...                  0.0       July 15th, 2017
# 278       1200  ...                  0.0   February 22nd, 2017
# 1146  500-700m  ...                  0.0       July 28th, 2015
# 269      950公尺  ...                  0.0   November 23rd, 2015
# 1021     550公尺  ...                  0.0   November 23rd, 2015
#
#                 certification_body                     certification_address  \
# 962   Specialty Coffee Association  36d0d00a3724338ba7937c52a378d085f2172daa
# 620   Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 1125  Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 825   Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 482   Specialty Coffee Association  36d0d00a3724338ba7937c52a378d085f2172daa
# 914   Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 770   Specialty Coffee Association  36d0d00a3724338ba7937c52a378d085f2172daa
# 1026  Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 919   Specialty Coffee Association  d3ed2a8c1db69c87daef88f425dd0e8ef3216a39
# 897   Specialty Coffee Association  36d0d00a3724338ba7937c52a378d085f2172daa
# 278   Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 1146  Specialty Coffee Association  36d0d00a3724338ba7937c52a378d085f2172daa
# 269   Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
# 1021  Blossom Valley International  fc45352eee499d8470cf94c9827922fb745bf815
#
#                          certification_contact unit_of_measurement  \
# 962   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 620   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 1125  de73fc9412358b523d3a641501e542f31d2668b0                   m
# 825   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 482   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 914   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 770   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 1026  de73fc9412358b523d3a641501e542f31d2668b0                   m
# 919   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 897   0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 278   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 1146  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 269   de73fc9412358b523d3a641501e542f31d2668b0                   m
# 1021  de73fc9412358b523d3a641501e542f31d2668b0                   m
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters weight
# 962                680.0                680.0                680.0      2
# 620               1240.0               1240.0               1240.0      2
# 1125               250.0                250.0                250.0      2
# 825               1000.0               1000.0               1000.0      2
# 482                700.0                800.0                750.0      2
# 914                160.0                200.0                180.0      2
# 770                800.0                800.0                800.0      2
# 1026               688.0                688.0                688.0      2
# 919                900.0                900.0                900.0      2
# 897                800.0                800.0                800.0      2
# 278               1200.0               1200.0               1200.0      2
# 1146               500.0                700.0                600.0      2
# 269                950.0                950.0                950.0      2
# 1021               550.0                550.0                550.0      2
#
# [14 rows x 44 columns]
