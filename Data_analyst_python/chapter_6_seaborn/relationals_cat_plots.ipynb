# %% [markdown]
# ## Difference between Line and scatter plots
#
# ##### Scatter plots
# - Each plot is and independent observation
#
# #### Line plots
# - Each plot point represents the same 'thing' typically tracked over time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Scatter plots

# %%
students = pd.read_csv('student-alcohol-consumption.csv', index_col= 0)
students.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures schoolsup  \
# 0     GP   F   18     GT3       A     4     4           2         0       yes
# 1     GP   F   17     GT3       T     1     1           1         0        no
# 2     GP   F   15     LE3       T     1     1           1         3       yes
# 3     GP   F   15     GT3       T     4     2           1         0        no
# 4     GP   F   16     GT3       T     3     3           1         0        no
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 29 columns]

# %%
sns.relplot(x="G1", y="G3", 
            data=students,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row = 'famsup',
            row_order = ['yes', 'no'],
            size = 'absences',    
            hue = 'absences', 
            alpha = 1        
            )

# Show plot
plt.show()

# %%
cars = pd.read_csv('mpg.csv')


sns.relplot(data = cars, kind = 'scatter', x = 'acceleration', y = 'mpg', style = 'origin', hue = 'origin')
plt.show()

# %% [markdown]
# #### Line plots

# %%
# Create line plot
sns.relplot(data = cars, kind = 'line', 
            x = 'model_year', 
            y = 'horsepower', 
            errorbar = None,
            style = 'origin',
            hue = 'origin',
            dashes = False,
            markers = True
            )

# Show plot
plt.show()

# %% [markdown]
# ### Count and bar plots
#
# ##### This are categorical type plot
# - Involves a categorical variable
# - Comparisons between groups
#
#
# ##### Catplot () is used to create categorical plots

# %%
students = pd.read_csv('student-alcohol-consumption.csv', index_col= 0)
students.head(2)
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures schoolsup  \
# 0     GP   F   18     GT3       A     4     4           2         0       yes
# 1     GP   F   17     GT3       T     1     1           1         0        no
#
#    ... goout Dalc Walc health absences G1 G2  G3  location    study_time
# 0  ...     4    1    1      3        6  5  6   6     Urban  2 to 5 hours
# 1  ...     3    1    1      3        4  5  5   6     Urban  2 to 5 hours
#
# [2 rows x 29 columns]

# %%
sns.catplot(data = students, kind = 'bar', 
                x = 'study_time', 
                y = 'G3',
                order = ["<2 hours", 
                        "2 to 5 hours", 
                        "5 to 10 hours", 
                        ">10 hours"],
                errorbar= None,
                hue = 'sex',
                palette = ['r', 'k']
                )

plt.title('Average Final Grade by Study Time')
plt.show()

# %%
# Boxplot

# Specify the category ordering
study_time_order = ["<2 hours", "2 to 5 hours", 
                    "5 to 10 hours", ">10 hours"]

# Create a box plot and set the order of the categories
sns.catplot(data = students, kind = 'box', x = 'study_time', y = 'G3', order = study_time_order)

# Show plot
plt.show()

# %%
# Create a box plot with subgroups and omit the outliers
sns.catplot(data = students, kind = 'box', 
            x = 'internet', 
            y = 'G3', 
            hue = 'location', 
            sym = '',
            whis = [10, 90]
            )

# Show plot
plt.show()

# %% [markdown]
# #### Point plots

# %%
# Import median function from numpy
from numpy import median

# Plot the median number of absences instead of the mean
sns.catplot(x="romantic", y="absences",
			data=students,
            kind="point",
            hue="school",
            errorbar = None,
            estimator = median)

# Show plot
plt.show()
