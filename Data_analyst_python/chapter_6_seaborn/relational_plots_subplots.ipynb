# %% [markdown]
# ## Difference between Line and scatter plots
#
# ##### Scatter plots
# - Each plot is and independent observation
#
# #### Line plots
# - Each plot point represents the same 'thing' typically tracked over time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Scatter plots

# %%
students = pd.read_csv('student-alcohol-consumption.csv', index_col= 0)
students.head()
# Out:
#   school sex  age famsize Pstatus  Medu  Fedu  traveltime  failures schoolsup  \
# 0     GP   F   18     GT3       A     4     4           2         0       yes
# 1     GP   F   17     GT3       T     1     1           1         0        no
# 2     GP   F   15     LE3       T     1     1           1         3       yes
# 3     GP   F   15     GT3       T     4     2           1         0        no
# 4     GP   F   16     GT3       T     3     3           1         0        no
#
#    ... goout Dalc Walc health absences  G1  G2  G3  location     study_time
# 0  ...     4    1    1      3        6   5   6   6     Urban   2 to 5 hours
# 1  ...     3    1    1      3        4   5   5   6     Urban   2 to 5 hours
# 2  ...     2    2    3      3       10   7   8  10     Urban   2 to 5 hours
# 3  ...     2    1    1      5        2  15  14  15     Urban  5 to 10 hours
# 4  ...     2    1    2      5        4   6  10  10     Urban   2 to 5 hours
#
# [5 rows x 29 columns]

# %%
sns.relplot(x="G1", y="G3", 
            data=students,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"],
            row = 'famsup',
            row_order = ['yes', 'no'],
            size = 'absences',    
            hue = 'absences', 
            alpha = 1        
            )

# Show plot
plt.show()

# %%
cars = pd.read_csv('mpg.csv')


sns.relplot(data = cars, kind = 'scatter', x = 'acceleration', y = 'mpg', style = 'origin', hue = 'origin')

# %% [markdown]
# #### Line plots

# %%
# Create line plot
sns.relplot(data = cars, kind = 'line', x = 'model_year', y = 'mpg')

# Show plot
plt.show()
# Out:
# c:\Users\codlw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\codlw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
